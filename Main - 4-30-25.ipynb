# %%
# %pip install openai
# %pip install unidecode
# %restart_python
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import json
import random
import openai
from openai import OpenAI
from pathlib import Path
from unidecode import unidecode

from pyspark.sql.functions import *

# %%
from translation import *
from config import *

# %%
# %run "./authentication script"

# %%
#exclude_languages = ['Russian'] # test this case



#TARGET_LANGUAGES.remove(*exclude_languages)

# %%
#LANG_MAP.pop('Russian')

# %%
LANG_MAP

# %%
#exclude_languages = ['Russian'] 
TRANSLATION_LANG_MAP = {**LANG_MAP}
for lang in exclude_languages:
  TRANSLATION_LANG_MAP.pop(lang)

# %%
TRANSLATION_LANG_MAP

# %%
#LANG_MAP

# %%
TARGET_LANGUAGES

# %%
###


# TODO:
# 1.) add input table for ios, add input table for android? or same/together

    # 1a) precrocess then add to table which will be grabbed for batch file creation (including english char limits, target lang char limits)

# 2.) TODO: modify prompt for new input structure; 
#   2a) create function to create batch files for each language and write to file 

# 3.) Run model


# 4.) process and output to results tables (add to table) for ios and android separately
